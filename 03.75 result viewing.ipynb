# %%
import pandas as pd
import os
from tqdm import tqdm
import matplotlib.pyplot as plt
import plotly.express as px

import xml.etree.ElementTree as ET
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ### Data

# %%
hpv_positive_genes = pd.read_csv('Results/SOM results/HPV positive top genes.csv')
hpv_negative_genes = pd.read_csv('Results/SOM results/HPV negative top genes.csv')

hpv_pos_som_top_direct = pd.read_csv('Results/SOM results/hpv_positive_som_top_direct_drug_candidates_agg.csv')
hpv_neg_som_top_direct = pd.read_csv('Results/SOM results/hpv_negative_som_top_direct_drug_candidates_agg.csv')

hpv_pos_som_top_indirect = pd.read_csv('Results/SOM results/hpv_positive_som_top_indirect_drug_candidates_agg.csv')
hpv_neg_som_top_indirect = pd.read_csv('Results/SOM results/hpv_negative_som_top_indirect_drug_candidates_agg.csv')

# %% [markdown]
# ### HPV+

# %%
hpv_positive_genes

# %%
hpv_pos_som_top_direct

# %%
hpv_pos_som_top_indirect

# %% [markdown]
# ### HPV-

# %%
hpv_negative_genes

# %%
hpv_neg_som_top_direct

# %%
hpv_neg_som_top_indirect
