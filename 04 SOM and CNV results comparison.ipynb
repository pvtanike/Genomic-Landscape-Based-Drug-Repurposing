# %%
import pandas as pd
import os
from tqdm import tqdm
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# ### Data

# %%
### CNV data
hpv_pos_amp_top_drugBank_drug_candidates = pd.read_csv('Results/CNV results/hpv_pos_amp_top_drugBank_drug_candidates.csv')
hpv_pos_del_top_drugBank_drug_candidates = pd.read_csv('Results/CNV results/hpv_pos_del_top_drugBank_drug_candidates.csv')

hpv_neg_amp_top_drugBank_drug_candidates = pd.read_csv('Results/CNV results/hpv_neg_amp_top_drugBank_drug_candidates.csv')
hpv_neg_del_top_drugBank_drug_candidates = pd.read_csv('Results/CNV results/hpv_neg_del_top_drugBank_drug_candidates.csv')

# %%
### som data
hpv_pos_som_top_drugBank_drug_candidates = pd.read_csv('Results/hpv_pos_som_top_drugBank_drug_candidates.csv')
hpv_neg_som_top_drugBank_drug_candidates = pd.read_csv('Results/hpv_neg_som_top_drugBank_drug_candidates.csv')

# %% [markdown]
# ### Compare results

# %% [markdown]
# #### HPV+

# %%
### Venn diagram for hpv pos genes
print(f'Number of genes in HPV positive amplification genes: {hpv_pos_amp_top_drugBank_drug_candidates['GENE_TARGET'].nunique()}')
print(f'overlap between hpv positive amplification and deletion: {len(set(hpv_pos_amp_top_drugBank_drug_candidates["GENE_TARGET"]).intersection(set(hpv_pos_del_top_drugBank_drug_candidates["GENE_TARGET"])))}')
print(f'Number of genes in HPV positive deletion genes: {hpv_pos_del_top_drugBank_drug_candidates['GENE_TARGET'].nunique()}')

print(f'Number of genes in hpv positive somatic genes: {hpv_pos_som_top_drugBank_drug_candidates['GENE_TARGET'].nunique()}')
print(f'overlap between hpv positive somatic and amplification: {len(set(hpv_pos_som_top_drugBank_drug_candidates["GENE_TARGET"]).intersection(set(hpv_pos_amp_top_drugBank_drug_candidates["GENE_TARGET"])))}')
print(f'overlap between hpv positive somatic and deletion: {len(set(hpv_pos_som_top_drugBank_drug_candidates["GENE_TARGET"]).intersection(set(hpv_pos_del_top_drugBank_drug_candidates["GENE_TARGET"])))}')

print(f'Overlap between hpv positive amplification and deletion and somatic: {len(set(hpv_pos_amp_top_drugBank_drug_candidates["GENE_TARGET"]).intersection(set(hpv_pos_som_top_drugBank_drug_candidates["GENE_TARGET"])).intersection(set(hpv_pos_del_top_drugBank_drug_candidates["GENE_TARGET"])))}')
# Out:
# Number of genes in HPV positive amplification genes: 353
# overlap between hpv positive amplification and deletion: 63
# Number of genes in HPV positive deletion genes: 102
# Number of genes in hpv positive somatic genes: 78
# overlap between hpv positive somatic and amplification: 68
# overlap between hpv positive somatic and deletion: 23
# Overlap between hpv positive amplification and deletion and somatic: 23

# %%
### Venn diagram for hpv pos drugs

print(f'Number of drugs in HPV positive amplification drugs: {hpv_pos_amp_top_drugBank_drug_candidates['DRUG'].nunique()}')
print(f'overlap between hpv positive amplification and deletion: {len(set(hpv_pos_amp_top_drugBank_drug_candidates["DRUG"]).intersection(set(hpv_pos_del_top_drugBank_drug_candidates["DRUG"])))}')
### those in hpv pos del not in amp
print('Number of Drugs in hpv pos del not in amp:')
print(len(set(hpv_pos_del_top_drugBank_drug_candidates['DRUG']) - set(hpv_pos_amp_top_drugBank_drug_candidates['DRUG'])))
### those in hpv pos amp not in del
print('Number of Drugs in hpv pos amp not in del:')
print(len(set(hpv_pos_amp_top_drugBank_drug_candidates['DRUG']) - set(hpv_pos_del_top_drugBank_drug_candidates['DRUG'])))


print(f'Number of drugs in HPV positive deletion drugs: {hpv_pos_del_top_drugBank_drug_candidates['DRUG'].nunique()}')

print(f'Number of drugs in hpv positive somatic drugs: {hpv_pos_som_top_drugBank_drug_candidates['DRUG'].nunique()}')
### only in som not in amp or del
print('Number of Drugs in hpv pos som not in amp or del:')
print(len(set(hpv_pos_som_top_drugBank_drug_candidates['DRUG']) - set(hpv_pos_amp_top_drugBank_drug_candidates['DRUG']) - set(hpv_pos_del_top_drugBank_drug_candidates['DRUG'])))
print(f'overlap between hpv positive somatic and amplification: {len(set(hpv_pos_som_top_drugBank_drug_candidates["DRUG"]).intersection(set(hpv_pos_amp_top_drugBank_drug_candidates["DRUG"])))}')
print(f'overlap between hpv positive somatic and deletion: {len(set(hpv_pos_som_top_drugBank_drug_candidates["DRUG"]).intersection(set(hpv_pos_del_top_drugBank_drug_candidates["DRUG"])))}')

print(f'Overlap between hpv positive amplification and deletion and somatic: {len(set(hpv_pos_amp_top_drugBank_drug_candidates["DRUG"]).intersection(set(hpv_pos_som_top_drugBank_drug_candidates["DRUG"])).intersection(set(hpv_pos_del_top_drugBank_drug_candidates["DRUG"])))}')
# Out:
# Number of drugs in HPV positive amplification drugs: 143
# overlap between hpv positive amplification and deletion: 32
# Number of Drugs in hpv pos del not in amp:
# 10
# Number of Drugs in hpv pos amp not in del:
# 111
# Number of drugs in HPV positive deletion drugs: 42
# Number of drugs in hpv positive somatic drugs: 91
# Number of Drugs in hpv pos som not in amp or del:
# 34
# overlap between hpv positive somatic and amplification: 57
# overlap between hpv positive somatic and deletion: 27
# Overlap between hpv positive amplification and deletion and somatic: 27

# %%
hpv_pos_amp_top_drugBank_drug_candidates
# Out:
#      GENE_TARGET CONNECTED_TO  PPI_SCORE                            DRUG  \
# 0           KNG1          HRG        972                            Zinc
# 1           KNG1          HRG        972                          Copper
# 2           KNG1          HRG        972                    Zinc acetate
# 3           KNG1          HRG        972                   Zinc chloride
# 4           KNG1          HRG        972  Zinc sulfate, unspecified form
# ...          ...          ...        ...                             ...
# 1869         HRG          NaN          0  Zinc sulfate, unspecified form
# 1870      PIK3CA          NaN          0                           XL765
# 1871      PIK3CA          NaN          0                      Buparlisib
# 1872      PIK3CA          NaN          0                      Copanlisib
# 1873      PIK3CA          NaN          0                      CH-5132799
#
#       GENE_GISTIC  GENE_normalized_gistic_score  GENE_frequency_percentage  \
# 0        0.302421                      0.242965                  33.484163
# 1        0.302421                      0.242965                  33.484163
# 2        0.302421                      0.242965                  33.484163
# 3        0.302421                      0.242965                  33.484163
# 4        0.302421                      0.242965                  33.484163
# ...           ...                           ...                        ...
# 1869     0.302421                      0.242965                  33.484163
# 1870     0.302482                      0.245792                  33.484163
# 1871     0.302482                      0.245792                  33.484163
# 1872     0.302482                      0.245792                  33.484163
# 1873     0.302482                      0.245792                  33.484163
#
#       GENE_SIGNIFICANT     ACTION  \
# 0                 True        NaN
# 1                 True        NaN
# 2                 True        NaN
# 3                 True   cofactor
# 4                 True   cofactor
# ...                ...        ...
# 1869              True   cofactor
# 1870              True        NaN
# 1871              True  inhibitor
# 1872              True  inhibitor
# 1873              True  inhibitor
#
#                                    SPECIFIC_FUNCTION  drug_hypergeom_p_value  \
# 0     cysteine-type endopeptidase inhibitor activity            2.168867e-13
# 1     cysteine-type endopeptidase inhibitor activity            8.218045e-15
# 2     cysteine-type endopeptidase inhibitor activity            2.168867e-13
# 3     cysteine-type endopeptidase inhibitor activity            4.050306e-15
# 4     cysteine-type endopeptidase inhibitor activity            4.050306e-15
# ...                                              ...                     ...
# 1869  cysteine-type endopeptidase inhibitor activity            4.050306e-15
# 1870        1-phosphatidylinositol-3-kinase activity            7.766063e-05
# 1871        1-phosphatidylinositol-3-kinase activity            5.168234e-04
# 1872        1-phosphatidylinositol-3-kinase activity            5.168234e-04
# 1873        1-phosphatidylinositol-3-kinase activity            5.168234e-04
#
#       drug_hypergeom_fdr  drug_empirical_p_value  drug_empirical_fdr  \
# 0           4.063589e-10                 0.00001            0.002037
# 1           2.566222e-11                 0.00001            0.002037
# 2           4.063589e-10                 0.00001            0.002037
# 3           1.897163e-11                 0.00001            0.002037
# 4           1.897163e-11                 0.00001            0.002037
# ...                  ...                     ...                 ...
# 1869        1.897163e-11                 0.00001            0.002037
# 1870        8.661009e-03                 0.00008            0.009029
# 1871        3.433760e-02                 0.00054            0.038913
# 1872        3.433760e-02                 0.00054            0.038913
# 1873        3.433760e-02                 0.00054            0.038913
#
#       HNC_approved_medication  DIRECT
# 0                       False       0
# 1                       False       0
# 2                       False       0
# 3                       False       0
# 4                       False       0
# ...                       ...     ...
# 1869                    False      17
# 1870                    False      17
# 1871                    False      17
# 1872                    False      17
# 1873                    False      17
#
# [1874 rows x 16 columns]

# %%
hpv_pos_del_top_drugBank_drug_candidates
# Out:
#     GENE_TARGET CONNECTED_TO  PPI_SCORE                     DRUG  GENE_GISTIC  \
# 0         HDAC2        SCML2        908               Vorinostat     0.091071
# 1         HDAC2        SCML2        908              Pracinostat     0.091071
# 2         HDAC2        SCML2        908              Martinostat     0.091071
# 3         RPL14       EIF2S3        835                Artenimol     0.091071
# 4          RPL3       EIF2S3        898  (S)-3-phenyllactic acid     0.091071
# ..          ...          ...        ...                      ...          ...
# 441       HDAC3        TBL1X        999              Pracinostat     0.091071
# 442       HDAC3        TBL1X        999              Martinostat     0.091071
# 443        TLR7          NaN          0                Golotimod     0.091071
# 444       POLA1          NaN          0               Cladribine     0.091071
# 445       VEGFD          NaN          0                TG-100801     0.091071
#
#      GENE_normalized_gistic_score  GENE_frequency_percentage  \
# 0                             0.0                  14.479638
# 1                             0.0                  14.479638
# 2                             0.0                  14.479638
# 3                             0.0                  14.479638
# 4                             0.0                  14.479638
# ..                            ...                        ...
# 441                           0.0                  14.479638
# 442                           0.0                  14.479638
# 443                           0.0                  14.479638
# 444                           0.0                  14.479638
# 445                           0.0                  14.479638
#
#      GENE_SIGNIFICANT     ACTION            SPECIFIC_FUNCTION  \
# 0                True  inhibitor            chromatin binding
# 1                True        NaN            chromatin binding
# 2                True  inhibitor            chromatin binding
# 3                True     ligand             cadherin binding
# 4                True        NaN                  RNA binding
# ..                ...        ...                          ...
# 441              True        NaN            chromatin binding
# 442              True  inhibitor            chromatin binding
# 443              True        NaN  double-stranded RNA binding
# 444              True  inhibitor            chromatin binding
# 445              True  inhibitor     chemoattractant activity
#
#      drug_hypergeom_p_value  drug_hypergeom_fdr  drug_empirical_p_value  \
# 0              8.755887e-05            0.029295                 0.00008
# 1              1.466201e-04            0.032703                 0.00012
# 2              5.640764e-06            0.002642                 0.00001
# 3              4.577312e-07            0.000306                 0.00001
# 4              4.394774e-07            0.000306                 0.00001
# ..                      ...                 ...                     ...
# 441            1.466201e-04            0.032703                 0.00012
# 442            5.640764e-06            0.002642                 0.00001
# 443            1.605536e-05            0.006539                 0.00006
# 444            9.203648e-05            0.029731                 0.00008
# 445            4.038151e-05            0.015762                 0.00006
#
#      drug_empirical_fdr  HNC_approved_medication  DIRECT
# 0              0.027757                    False       0
# 1              0.035130                    False       0
# 2              0.004684                    False       0
# 3              0.004684                    False       0
# 4              0.004684                    False       0
# ..                  ...                      ...     ...
# 441            0.035130                    False       0
# 442            0.004684                    False       0
# 443            0.023420                    False       3
# 444            0.027757                    False       3
# 445            0.023420                    False       3
#
# [446 rows x 16 columns]

# %%
### show drugs of overlap
hpv_pos_drug_overlap = set(hpv_pos_amp_top_drugBank_drug_candidates["DRUG"]).intersection(
	set(hpv_pos_som_top_drugBank_drug_candidates["DRUG"])
).intersection(set(hpv_pos_del_top_drugBank_drug_candidates["DRUG"]))

top_hpv_pos_overlap_drug = hpv_pos_amp_top_drugBank_drug_candidates[
	hpv_pos_amp_top_drugBank_drug_candidates["DRUG"].isin(hpv_pos_drug_overlap)
]
top_hpv_pos_overlap_drug.drop_duplicates(subset=('DRUG', 'GENE_TARGET'), inplace=True)
top_hpv_pos_overlap_drug
# Out:
# /var/folders/5p/swntgnbj3fbfxkx02kt3fq980000gn/T/ipykernel_91011/3204924084.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_hpv_pos_overlap_drug.drop_duplicates(subset=('DRUG', 'GENE_TARGET'), inplace=True)
#      GENE_TARGET CONNECTED_TO  PPI_SCORE          DRUG  GENE_GISTIC  \
# 160       MAPK11         GNB4        737   Regorafenib     0.302084
# 221       MAPK14         GNB4        738     PD-166326     0.302084
# 432        IGF1R       PIK3CA        978    Brigatinib     0.302482
# 445         RAF1       PIK3CA        972     Sorafenib     0.302482
# 446         RAF1       PIK3CA        972   Regorafenib     0.302482
# ...          ...          ...        ...           ...          ...
# 842         FLT3       PIK3CA        958    Brigatinib     0.302482
# 843         FLT3       PIK3CA        958    Amuvatinib     0.302482
# 844         FLT3       PIK3CA        958  Pexidartinib     0.302482
# 1167       EPHA2        CLDN1        704   Regorafenib     0.297817
# 1300       RAD51         RFC4        888    Amuvatinib     0.302421
#
#       GENE_normalized_gistic_score  GENE_frequency_percentage  \
# 160                       0.227500                  33.484163
# 221                       0.227500                  33.484163
# 432                       0.245792                  33.484163
# 445                       0.245792                  33.484163
# 446                       0.245792                  33.484163
# ...                            ...                        ...
# 842                       0.245792                  33.484163
# 843                       0.245792                  33.484163
# 844                       0.245792                  33.484163
# 1167                      0.031631                  33.031674
# 1300                      0.242965                  33.484163
#
#       GENE_SIGNIFICANT     ACTION SPECIFIC_FUNCTION  drug_hypergeom_p_value  \
# 160               True  inhibitor       ATP binding            2.203707e-10
# 221               True  inhibitor       ATP binding            3.905673e-08
# 432               True  inhibitor       ATP binding            3.905673e-08
# 445               True  inhibitor       ATP binding            8.686883e-10
# 446               True  inhibitor       ATP binding            2.203707e-10
# ...                ...        ...               ...                     ...
# 842               True  inhibitor       ATP binding            3.905673e-08
# 843               True        NaN       ATP binding            1.165378e-05
# 844               True  inhibitor       ATP binding            5.168234e-04
# 1167              True  inhibitor       ATP binding            2.203707e-10
# 1300              True        NaN       ATP binding            1.165378e-05
#
#       drug_hypergeom_fdr  drug_empirical_p_value  drug_empirical_fdr  \
# 160         2.949189e-07                 0.00001            0.002037
# 221         1.590798e-05                 0.00001            0.002037
# 432         1.590798e-05                 0.00001            0.002037
# 445         1.017234e-06                 0.00001            0.002037
# 446         2.949189e-07                 0.00001            0.002037
# ...                  ...                     ...                 ...
# 842         1.590798e-05                 0.00001            0.002037
# 843         2.228012e-03                 0.00004            0.006574
# 844         3.433760e-02                 0.00043            0.037298
# 1167        2.949189e-07                 0.00001            0.002037
# 1300        2.228012e-03                 0.00004            0.006574
#
#       HNC_approved_medication  DIRECT
# 160                     False       0
# 221                     False       0
# 432                     False       0
# 445                     False       0
# 446                     False       0
# ...                       ...     ...
# 842                     False       0
# 843                     False       0
# 844                     False       0
# 1167                    False       0
# 1300                    False       0
#
# [199 rows x 16 columns]

# %%
hpv_pos_drug_overlap
# Out:
# {'Amuvatinib',
#  'BMS-690514',
#  'Brigatinib',
#  'Erdafitinib',
#  'Famitinib',
#  'Futibatinib',
#  'Infigratinib',
#  'Lenvatinib',
#  'Linifanib',
#  'Lucitanib',
#  'Nintedanib',
#  'PD-166326',
#  'Pazopanib',
#  'Pemigatinib',
#  'Pexidartinib',
#  'Ponatinib',
#  'Regorafenib',
#  'Ripretinib',
#  'Selpercatinib',
#  'Semaxanib',
#  'Sorafenib',
#  'Sunitinib',
#  'Surufatinib',
#  'Tivozanib',
#  'Vatalanib',
#  'XL820',
#  'XL999'}

# %% [markdown]
# #### HPV-

# %%
### Venn diagram for hpv neg genes
print(f'Number of genes in HPV negative amplification genes: {hpv_neg_amp_top_drugBank_drug_candidates['GENE_TARGET'].nunique()}')
print(f'overlap between hpv negative amplification and deletion: {len(set(hpv_neg_amp_top_drugBank_drug_candidates["GENE_TARGET"]).intersection(set(hpv_neg_del_top_drugBank_drug_candidates["GENE_TARGET"])))}')
print(f'Number of genes in HPV negative deletion genes: {hpv_neg_del_top_drugBank_drug_candidates['GENE_TARGET'].nunique()}')

print(f'Number of genes in hpv negative somatic genes: {hpv_neg_som_top_drugBank_drug_candidates['GENE_TARGET'].nunique()}')
print(f'overlap between hpv negative somatic and amplification: {len(set(hpv_neg_som_top_drugBank_drug_candidates["GENE_TARGET"]).intersection(set(hpv_neg_amp_top_drugBank_drug_candidates["GENE_TARGET"])))}')
print(f'overlap between hpv negative somatic and deletion: {len(set(hpv_neg_som_top_drugBank_drug_candidates["GENE_TARGET"]).intersection(set(hpv_neg_del_top_drugBank_drug_candidates["GENE_TARGET"])))}')

print(f'Overlap between hpv negative amplification and deletion and somatic: {len(set(hpv_neg_amp_top_drugBank_drug_candidates["GENE_TARGET"]).intersection(set(hpv_neg_som_top_drugBank_drug_candidates["GENE_TARGET"])).intersection(set(hpv_neg_del_top_drugBank_drug_candidates["GENE_TARGET"])))}')
# Out:
# Number of genes in HPV negative amplification genes: 436
# overlap between hpv negative amplification and deletion: 52
# Number of genes in HPV negative deletion genes: 68
# Number of genes in hpv negative somatic genes: 306
# overlap between hpv negative somatic and amplification: 122
# overlap between hpv negative somatic and deletion: 32
# Overlap between hpv negative amplification and deletion and somatic: 26

# %%
### Venn diagram for hpv neg drugs
print(f'Number of drugs in HPV negative amplification drugs: {hpv_neg_amp_top_drugBank_drug_candidates['DRUG'].nunique()}')
print(f'overlap between hpv negative amplification and deletion: {len(set(hpv_neg_amp_top_drugBank_drug_candidates["DRUG"]).intersection(set(hpv_neg_del_top_drugBank_drug_candidates["DRUG"])))}')
print(f'Number of drugs in HPV negative deletion drugs: {hpv_neg_del_top_drugBank_drug_candidates['DRUG'].nunique()}')

print(f'Number of drugs in hpv negative somatic drugs: {hpv_neg_som_top_drugBank_drug_candidates['DRUG'].nunique()}')
print(f'overlap between hpv negative somatic and amplification: {len(set(hpv_neg_som_top_drugBank_drug_candidates["DRUG"]).intersection(set(hpv_neg_amp_top_drugBank_drug_candidates["DRUG"])))}')
print(f'overlap between hpv negative somatic and deletion: {len(set(hpv_neg_som_top_drugBank_drug_candidates["DRUG"]).intersection(set(hpv_neg_del_top_drugBank_drug_candidates["DRUG"])))}')

print(f'Overlap between hpv negative amplification and deletion and somatic: {len(set(hpv_neg_amp_top_drugBank_drug_candidates["DRUG"]).intersection(set(hpv_neg_som_top_drugBank_drug_candidates["DRUG"])).intersection(set(hpv_neg_del_top_drugBank_drug_candidates["DRUG"])))}')
# Out:
# Number of drugs in HPV negative amplification drugs: 85
# overlap between hpv negative amplification and deletion: 12
# Number of drugs in HPV negative deletion drugs: 31
# Number of drugs in hpv negative somatic drugs: 46
# overlap between hpv negative somatic and amplification: 28
# overlap between hpv negative somatic and deletion: 12
# Overlap between hpv negative amplification and deletion and somatic: 9

# %%
### hpv negative top overlap drughs
hpv_neg_drug_overlap = set(hpv_neg_amp_top_drugBank_drug_candidates["DRUG"]).intersection(
    set(hpv_neg_som_top_drugBank_drug_candidates["DRUG"])
).intersection(set(hpv_neg_del_top_drugBank_drug_candidates["DRUG"]))
hpv_neg_drug_overlap
# Out:
# {'Artenimol',
#  'Bisindolylmaleimide I',
#  'Brigatinib',
#  'CI-1040',
#  'Enzastaurin',
#  'PD-166326',
#  'PP-121',
#  'Ponatinib',
#  'Tetrabromo-2-Benzotriazole'}

# %%
### combine top candidate information from sources
hpv_neg_top_drug_candidate_information = pd.concat(
    [hpv_neg_amp_top_drugBank_drug_candidates, hpv_neg_del_top_drugBank_drug_candidates, hpv_neg_som_top_drugBank_drug_candidates],
    ignore_index=True
)
hpv_neg_top_drug_candidate_information = hpv_neg_top_drug_candidate_information[hpv_neg_top_drug_candidate_information['DRUG'].isin(hpv_neg_drug_overlap)]
hpv_neg_top_drug_candidate_information['CONNECTED_TO'].fillna('', inplace=True)
### aggregate this to show how many genes each drug targets
agg_hpv_neg_drug_candidate_information = hpv_neg_top_drug_candidate_information.groupby('DRUG').agg({
    'GENE_TARGET': lambda x: ', '.join(set(x)),
    'CONNECTED_TO': lambda x: ','.join(set(x)),
    'drug_hypergeom_fdr': 'min',
    'drug_empirical_fdr': 'min',
}).reset_index()

agg_hpv_neg_drug_candidate_information['num_targeted_genes'] = agg_hpv_neg_drug_candidate_information['GENE_TARGET'].apply(lambda x: len(x.split(', ')))
agg_hpv_neg_drug_candidate_information['num_connected_to'] = agg_hpv_neg_drug_candidate_information['CONNECTED_TO'].apply(lambda x: len(set(x.split(','))))
agg_hpv_neg_drug_candidate_information = agg_hpv_neg_drug_candidate_information.sort_values(by=['drug_hypergeom_fdr', 'drug_empirical_fdr'], ascending=[True, True]).reset_index(drop=True)
agg_hpv_neg_drug_candidate_information
# Out:
# /var/folders/5p/swntgnbj3fbfxkx02kt3fq980000gn/T/ipykernel_91011/3021201030.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hpv_neg_top_drug_candidate_information['CONNECTED_TO'].fillna('', inplace=True)
#                          DRUG  \
# 0                   Artenimol
# 1       Bisindolylmaleimide I
# 2                   Ponatinib
# 3                     CI-1040
# 4                      PP-121
# 5                  Brigatinib
# 6                   PD-166326
# 7  Tetrabromo-2-Benzotriazole
# 8                 Enzastaurin
#
#                                          GENE_TARGET  \
# 0  RPL10, ALDOA, MYH9, CLIC1, TAGLN, HNRNPD, RPS9...
# 1  PDPK1, MAPK8, GSK3B, LCK, MAPK12, CHEK1, MAPK1...
# 2  LYN, LCK, FGFR4, FGFR2, RET, KIT, FLT3, SRC, K...
# 3  MAPK8, GSK3B, CHEK1, LCK, MAPK12, MAPK14, RPS6...
# 4  PIK3CB, PRKDC, MTOR, SRC, PIK3CG, KDR, HCK, PD...
# 5  ABL1, ERBB4, FLT3, INSR, ERBB2, MET, IGF1R, EG...
# 6  LCK, MAPK14, PDGFRB, KIT, SRC, PDGFRA, EGFR, F...
# 7  MAPK8, GSK3B, CHEK1, LCK, MAPK12, MAPK14, RPS6...
# 8  CHEK2, CHEK1, AURKA, PIK3R1, PIK3CG, AKT1, PRK...
#
#                                         CONNECTED_TO  drug_hypergeom_fdr  \
# 0  EIF4G1,EIF1AY,KNG1,EHHADH,RBMY1A1,RPL39L,IGF2B...        4.169813e-07
# 1  ,ADIPOQ,RFC4,GNB4,MRPL47,MECOM,PRKCI,TP53,ADCY...        2.371705e-06
# 2         FGF12,THPO,IL1RAP,KNG1,EPHB3,CDKN2A,PIK3CA        4.725309e-06
# 3  EIF4G1,ADIPOQ,RFC4,GNB4,MRPL47,MECOM,TP53,ADCY...        1.747181e-04
# 4  EIF4G1,THPO,PRKCI,PIK3CA,TP53,KNG1,IGF2BP2,EPH...        2.393902e-04
# 5  THPO,PIK3CA,SLC2A2,IGF2BP2,EPHB3,SOX2,CDKN2A,A...        3.215223e-04
# 6  FGF12,THPO,GNB4,IL1RAP,AP2M1,TP53,KNG1,IGF2BP2...        3.215223e-04
# 7  EIF4G1,ADIPOQ,RFC4,GNB4,MRPL47,MECOM,TP53,ADCY...        5.129948e-04
# 8  ADIPOQ,RFC4,GNB4,PRKCI,TP53,ADCY2,AJUBA,ECT2,S...        1.659620e-03
#
#    drug_empirical_fdr  num_targeted_genes  num_connected_to
# 0            0.002532                  66                46
# 1            0.002532                  15                15
# 2            0.002532                  14                 7
# 3            0.002532                  12                15
# 4            0.002532                  10                11
# 5            0.002532                   9                 8
# 6            0.002532                   9                12
# 7            0.002532                  14                15
# 8            0.005855                   8                11

# %%
agg_hpv_neg_drug_candidate_information
# Out:
#                          DRUG  \
# 0                   Artenimol
# 1       Bisindolylmaleimide I
# 2                   Ponatinib
# 3                     CI-1040
# 4                      PP-121
# 5                  Brigatinib
# 6                   PD-166326
# 7  Tetrabromo-2-Benzotriazole
# 8                 Enzastaurin
#
#                                          GENE_TARGET  \
# 0  RPL10, ALDOA, MYH9, CLIC1, TAGLN, HNRNPD, RPS9...
# 1  PDPK1, MAPK8, GSK3B, LCK, MAPK12, CHEK1, MAPK1...
# 2  LYN, LCK, FGFR4, FGFR2, RET, KIT, FLT3, SRC, K...
# 3  MAPK8, GSK3B, CHEK1, LCK, MAPK12, MAPK14, RPS6...
# 4  PIK3CB, PRKDC, MTOR, SRC, PIK3CG, KDR, HCK, PD...
# 5  ABL1, ERBB4, FLT3, INSR, ERBB2, MET, IGF1R, EG...
# 6  LCK, MAPK14, PDGFRB, KIT, SRC, PDGFRA, EGFR, F...
# 7  MAPK8, GSK3B, CHEK1, LCK, MAPK12, MAPK14, RPS6...
# 8  CHEK2, CHEK1, AURKA, PIK3R1, PIK3CG, AKT1, PRK...
#
#                                         CONNECTED_TO  drug_hypergeom_fdr  \
# 0  EIF4G1,EIF1AY,KNG1,EHHADH,RBMY1A1,RPL39L,IGF2B...        4.169813e-07
# 1  ,ADIPOQ,RFC4,GNB4,MRPL47,MECOM,PRKCI,TP53,ADCY...        2.371705e-06
# 2         FGF12,THPO,IL1RAP,KNG1,EPHB3,CDKN2A,PIK3CA        4.725309e-06
# 3  EIF4G1,ADIPOQ,RFC4,GNB4,MRPL47,MECOM,TP53,ADCY...        1.747181e-04
# 4  EIF4G1,THPO,PRKCI,PIK3CA,TP53,KNG1,IGF2BP2,EPH...        2.393902e-04
# 5  THPO,PIK3CA,SLC2A2,IGF2BP2,EPHB3,SOX2,CDKN2A,A...        3.215223e-04
# 6  FGF12,THPO,GNB4,IL1RAP,AP2M1,TP53,KNG1,IGF2BP2...        3.215223e-04
# 7  EIF4G1,ADIPOQ,RFC4,GNB4,MRPL47,MECOM,TP53,ADCY...        5.129948e-04
# 8  ADIPOQ,RFC4,GNB4,PRKCI,TP53,ADCY2,AJUBA,ECT2,S...        1.659620e-03
#
#    drug_empirical_fdr  num_targeted_genes  num_connected_to
# 0            0.002532                  66                46
# 1            0.002532                  15                15
# 2            0.002532                  14                 7
# 3            0.002532                  12                15
# 4            0.002532                  10                11
# 5            0.002532                   9                 8
# 6            0.002532                   9                12
# 7            0.002532                  14                15
# 8            0.005855                   8                11
